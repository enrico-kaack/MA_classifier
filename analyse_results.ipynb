# %%
import pandas as pd
import json
import os

# %%
pd.set_option("display.max.columns", None)
pd.set_option("display.precision", 4)

# %%
frames = []
for root, dirs, files in os.walk("results/training_2"):
   for name in files:
      if name.endswith(".json"):
          frame = pd.read_json(os.path.join(root, name), orient="record", lines=True)
          frames.append(frame)
results = pd.concat(frames)

# %%
columns = ['task_id',  'problem_type', 'f1', 'recall', 'precision', 'roc', 'oversampling_enabled', 'ratio_after_oversampling', 'undersampling_enabled', 'ratio_after_undersampling', 'cm', 'cm_normalized', 'n_estimators', 'learning_rate', 'subsample', 'embedding_vecor_length', 'epochs', 'batch_size', 'num_lstm_cells', 'dropout_emb_lstm', 'dropout_lstm_dense', 'n_trees_in_forest', 'max_features', 'input_src_path', 'max_vocab_size', 'window_size', 'step_size', 'encode_type', 'test_split_percentage']
#'svm_kernel', 'svm_predict_probability', 'svm_class_weight'
results = results[columns]
results.head()
# Out:
#                                              task_id  \
# 0  TaskEvaluateGradientBoostingClassifier_True_se...
# 0             TaskEvaluateLstm_64_0_2_0_2_98d45eb0ff
# 0            TaskEvaluateLstm_256_0_2_0_2_08248931e9
# 0  TaskEvaluateRandomForest_True_second_large_dat...
# 0  TaskEvaluateGradientBoostingClassifier_True_se...
#
#                   problem_type      f1  recall  precision     roc  \
# 0                  RETURN_NULL  0.2448  0.9916     0.1396  0.9990
# 0         CONDITION_COMPARISON  0.9677  0.9978     0.9394  0.9999
# 0  CONDITION_COMPARISON_SIMPLE  0.9550  0.9991     0.9147  0.9999
# 0                  RETURN_NULL  0.8269  0.7094     0.9910  0.9984
# 0         CONDITION_COMPARISON  0.6087  0.8634     0.4700  0.9737
#
#    oversampling_enabled  ratio_after_oversampling  undersampling_enabled  \
# 0                 False                       0.5                   True
# 0                 False                       0.5                   True
# 0                 False                       0.5                   True
# 0                  True                       1.0                  False
# 0                 False                       0.5                   True
#
#    ratio_after_undersampling                                 cm  \
# 0                        0.5     [[1342820, 18079], [25, 2934]]
# 0                        0.5    [[1293462, 4255], [144, 65997]]
# 0                        0.5     [[1324131, 3386], [32, 36309]]
# 0                        0.5       [[1360880, 19], [860, 2099]]
# 0                        0.5  [[1233324, 64393], [9034, 57107]]
#
#                                        cm_normalized  n_estimators  \
# 0  [[0.986715399158938, 0.013284600841061001], [0...         100.0
# 0  [[0.9967211649381181, 0.0032788350618810002], ...           NaN
# 0  [[0.9974493735296791, 0.0025506264703200002], ...           NaN
# 0  [[0.9999860386406331, 1.3961359366124892e-05],...           NaN
# 0  [[0.9503797823408341, 0.049620217659166], [0.1...        1000.0
#
#    learning_rate  subsample  embedding_vecor_length  epochs  batch_size  \
# 0           0.20        1.0                     NaN     NaN         NaN
# 0            NaN        NaN                    32.0     3.0        64.0
# 0            NaN        NaN                    32.0     3.0       256.0
# 0            NaN        NaN                     NaN     NaN         NaN
# 0           0.01        1.0                     NaN     NaN         NaN
#
#    num_lstm_cells  dropout_emb_lstm  dropout_lstm_dense  n_trees_in_forest  \
# 0             NaN               NaN                 NaN                NaN
# 0            10.0               0.2                 0.2                NaN
# 0           100.0               0.2                 0.2                NaN
# 0             NaN               NaN                 NaN              100.0
# 0             NaN               NaN                 NaN                NaN
#
#   max_features        input_src_path  max_vocab_size  window_size  step_size  \
# 0          NaN  second_large_dataset          100000           20          3
# 0          NaN  second_large_dataset          100000           20          3
# 0          NaN  second_large_dataset          100000           20          3
# 0         sqrt  second_large_dataset            1000           20          3
# 0          NaN  second_large_dataset          100000           20          3
#
#    encode_type  test_split_percentage
# 0         True                   0.25
# 0        False                   0.25
# 0        False                   0.25
# 0         True                   0.25
# 0         True                   0.25

# %% [markdown]
# # Return Null

# %%
return_none = results[(results["problem_type"] == "RETURN_NULL")  & (results["max_vocab_size"] == 100000)]
return_none.sort_values(by="f1", ascending=False)
# Out:
#                                              task_id problem_type      f1  \
# 0            TaskEvaluateLstm_256_0_2_0_2_f1ffaee6ac  RETURN_NULL  0.9860
# 0  TaskEvaluateRandomForest_True_second_large_dat...  RETURN_NULL  0.8257
# 0  TaskEvaluateRandomForest_True_second_large_dat...  RETURN_NULL  0.8209
# 0             TaskEvaluateLstm_64_0_2_0_2_177ca6702e  RETURN_NULL  0.7952
# 0            TaskEvaluateLstm_256_0_2_0_2_f89a65d0b2  RETURN_NULL  0.6457
# 0  TaskEvaluateRandomForest_True_second_large_dat...  RETURN_NULL  0.6047
# 0  TaskEvaluateGradientBoostingClassifier_True_se...  RETURN_NULL  0.2448
# 0  TaskEvaluateRandomForest_True_second_large_dat...  RETURN_NULL  0.2164
# 0  TaskEvaluateGradientBoostingClassifier_True_se...  RETURN_NULL  0.1671
# 0  TaskEvaluateGradientBoostingClassifier_True_se...  RETURN_NULL  0.1636
#
#    recall  precision     roc  oversampling_enabled  ratio_after_oversampling  \
# 0  0.9963     0.9758  1.0000                 False                       0.5
# 0  0.7060     0.9943  0.9988                  True                       0.5
# 0  0.6985     0.9952  0.9981                  True                       1.0
# 0  1.0000     0.6600  0.9998                 False                       0.5
# 0  1.0000     0.4768  0.9999                 False                       0.5
# 0  0.9040     0.4543  0.9989                 False                       0.5
# 0  0.9916     0.1396  0.9990                 False                       0.5
# 0  0.9699     0.1218  0.9979                 False                       0.5
# 0  0.9713     0.0914  0.9966                 False                       0.5
# 0  0.9696     0.0893  0.9964                 False                       0.5
#
#    undersampling_enabled  ratio_after_undersampling  \
# 0                  False                        0.5
# 0                  False                        0.5
# 0                  False                        0.5
# 0                   True                        0.5
# 0                   True                        0.5
# 0                   True                        0.1
# 0                   True                        0.5
# 0                   True                        0.5
# 0                   True                        0.5
# 0                   True                        0.5
#
#                                cm  \
# 0     [[1360826, 73], [11, 2948]]
# 0    [[1360887, 12], [870, 2089]]
# 0    [[1360889, 10], [892, 2067]]
# 0    [[1359375, 1524], [0, 2959]]
# 0    [[1357652, 3247], [0, 2959]]
# 0  [[1357686, 3213], [284, 2675]]
# 0  [[1342820, 18079], [25, 2934]]
# 0  [[1340204, 20695], [89, 2870]]
# 0  [[1332324, 28575], [85, 2874]]
# 0  [[1331655, 29244], [90, 2869]]
#
#                                        cm_normalized  n_estimators  \
# 0  [[0.9999463589876981, 5.364101230142723e-05], ...           NaN
# 0  [[0.999991182299347, 8.817700652289405e-06], [...           NaN
# 0  [[0.9999926519161231, 7.348083876907838e-06], ...           NaN
# 0  [[0.9988801520171591, 0.0011198479828400001], ...           NaN
# 0  [[0.997614077165168, 0.0023859228348310003], [...           NaN
# 0  [[0.9976390606503491, 0.00236093934965], [0.09...           NaN
# 0  [[0.986715399158938, 0.013284600841061001], [0...         100.0
# 0  [[0.984793140416739, 0.01520685958326], [0.030...           NaN
# 0  [[0.9790028503217351, 0.020997149678264], [0.0...         100.0
# 0  [[0.9785112635103701, 0.021488736489629002], [...        1000.0
#
#    learning_rate  subsample  embedding_vecor_length  epochs  batch_size  \
# 0            NaN        NaN                    32.0     2.0       256.0
# 0            NaN        NaN                     NaN     NaN         NaN
# 0            NaN        NaN                     NaN     NaN         NaN
# 0            NaN        NaN                    32.0     3.0        64.0
# 0            NaN        NaN                    32.0     3.0       256.0
# 0            NaN        NaN                     NaN     NaN         NaN
# 0           0.20        1.0                     NaN     NaN         NaN
# 0            NaN        NaN                     NaN     NaN         NaN
# 0           0.10        1.0                     NaN     NaN         NaN
# 0           0.01        1.0                     NaN     NaN         NaN
#
#    num_lstm_cells  dropout_emb_lstm  dropout_lstm_dense  n_trees_in_forest  \
# 0            10.0               0.2                 0.2                NaN
# 0             NaN               NaN                 NaN              100.0
# 0             NaN               NaN                 NaN              100.0
# 0            10.0               0.2                 0.2                NaN
# 0           100.0               0.2                 0.2                NaN
# 0             NaN               NaN                 NaN              100.0
# 0             NaN               NaN                 NaN                NaN
# 0             NaN               NaN                 NaN              100.0
# 0             NaN               NaN                 NaN                NaN
# 0             NaN               NaN                 NaN                NaN
#
#   max_features        input_src_path  max_vocab_size  window_size  step_size  \
# 0          NaN  second_large_dataset          100000           20          3
# 0         sqrt  second_large_dataset          100000           20          3
# 0         sqrt  second_large_dataset          100000           20          3
# 0          NaN  second_large_dataset          100000           20          3
# 0          NaN  second_large_dataset          100000           20          3
# 0         sqrt  second_large_dataset          100000           20          3
# 0          NaN  second_large_dataset          100000           20          3
# 0         sqrt  second_large_dataset          100000           20          3
# 0          NaN  second_large_dataset          100000           20          3
# 0          NaN  second_large_dataset          100000           20          3
#
#    encode_type  test_split_percentage
# 0        False                   0.25
# 0         True                   0.25
# 0         True                   0.25
# 0        False                   0.25
# 0        False                   0.25
# 0         True                   0.25
# 0         True                   0.25
# 0         True                   0.25
# 0         True                   0.25
# 0         True                   0.25

# %% [markdown]
# # Condition Comparison

# %%
return_condition = results[results["problem_type"] == "CONDITION_COMPARISON"] 
return_condition.sort_values(by="f1", ascending=False)
# Out:
#                                              task_id          problem_type  \
# 0            TaskEvaluateLstm_256_0_2_0_2_bde8bd6e01  CONDITION_COMPARISON
# 0            TaskEvaluateLstm_256_0_2_0_2_362ef35d62  CONDITION_COMPARISON
# 0             TaskEvaluateLstm_64_0_2_0_2_98d45eb0ff  CONDITION_COMPARISON
# 0  TaskEvaluateRandomForest_True_second_large_dat...  CONDITION_COMPARISON
# 0  TaskEvaluateRandomForest_True_second_large_dat...  CONDITION_COMPARISON
# 0  TaskEvaluateRandomForest_True_second_large_dat...  CONDITION_COMPARISON
# 0  TaskEvaluateRandomForest_False_second_large_da...  CONDITION_COMPARISON
# 0  TaskEvaluateRandomForest_False_second_large_da...  CONDITION_COMPARISON
# 0  TaskEvaluateRandomForest_True_second_large_dat...  CONDITION_COMPARISON
# 0  TaskEvaluateRandomForest_False_second_large_da...  CONDITION_COMPARISON
# 0  TaskEvaluateGradientBoostingClassifier_True_se...  CONDITION_COMPARISON
# 0  TaskEvaluateGradientBoostingClassifier_True_se...  CONDITION_COMPARISON
# 0  TaskEvaluateGradientBoostingClassifier_True_se...  CONDITION_COMPARISON
#
#        f1  recall  precision     roc  oversampling_enabled  \
# 0  0.9811  0.9890     0.9733  0.9999                 False
# 0  0.9715  0.9982     0.9462  0.9999                 False
# 0  0.9677  0.9978     0.9394  0.9999                 False
# 0  0.9370  0.9009     0.9760  0.9988                  True
# 0  0.9360  0.8993     0.9759  0.9988                  True
# 0  0.9330  0.9041     0.9639  0.9985                 False
# 0  0.9291  0.8875     0.9749  0.9986                  True
# 0  0.9262  0.8823     0.9747  0.9985                  True
# 0  0.8606  0.9595     0.7802  0.9974                 False
# 0  0.8579  0.9577     0.7769  0.9971                 False
# 0  0.7210  0.9401     0.5848  0.9891                 False
# 0  0.6115  0.8695     0.4716  0.9743                 False
# 0  0.6087  0.8634     0.4700  0.9737                 False
#
#    ratio_after_oversampling  undersampling_enabled  ratio_after_undersampling  \
# 0                       0.5                  False                        0.5
# 0                       0.5                   True                        0.5
# 0                       0.5                   True                        0.5
# 0                       0.5                  False                        0.5
# 0                       1.0                  False                        0.5
# 0                       0.5                   True                        0.1
# 0                       0.5                  False                        0.5
# 0                       1.0                  False                        0.5
# 0                       0.5                   True                        0.5
# 0                       0.5                   True                        0.5
# 0                       0.5                   True                        0.5
# 0                       0.5                   True                        0.5
# 0                       0.5                   True                        0.5
#
#                                   cm  \
# 0    [[1295922, 1795], [727, 65414]]
# 0    [[1293965, 3752], [121, 66020]]
# 0    [[1293462, 4255], [144, 65997]]
# 0   [[1296252, 1465], [6554, 59587]]
# 0   [[1296251, 1466], [6663, 59478]]
# 0   [[1295476, 2241], [6342, 59799]]
# 0   [[1296205, 1512], [7441, 58700]]
# 0   [[1296205, 1512], [7782, 58359]]
# 0  [[1279838, 17879], [2680, 63461]]
# 0  [[1279529, 18188], [2799, 63342]]
# 0  [[1253568, 44149], [3963, 62178]]
# 0  [[1233268, 64449], [8629, 57512]]
# 0  [[1233324, 64393], [9034, 57107]]
#
#                                        cm_normalized  n_estimators  \
# 0  [[0.9986168016601461, 0.001383198339853], [0.0...           NaN
# 0  [[0.99710876870689, 0.0028912312931090004], [0...           NaN
# 0  [[0.9967211649381181, 0.0032788350618810002], ...           NaN
# 0  [[0.99887109439115, 0.00112890560885], [0.0990...           NaN
# 0  [[0.998870323807116, 0.0011296761928830002], [...           NaN
# 0  [[0.9982731211812741, 0.0017268788187250002], ...           NaN
# 0  [[0.9988348769415821, 0.001165123058417], [0.1...           NaN
# 0  [[0.9988348769415821, 0.001165123058417], [0.1...           NaN
# 0  [[0.9862227280678291, 0.013777271932170002], [...           NaN
# 0  [[0.9859846176015261, 0.014015382398473001], [...           NaN
# 0  [[0.9659794855118641, 0.034020514488135], [0.0...         100.0
# 0  [[0.9503366296349661, 0.049663370365033], [0.1...         100.0
# 0  [[0.9503797823408341, 0.049620217659166], [0.1...        1000.0
#
#    learning_rate  subsample  embedding_vecor_length  epochs  batch_size  \
# 0            NaN        NaN                    32.0     2.0       256.0
# 0            NaN        NaN                    32.0     3.0       256.0
# 0            NaN        NaN                    32.0     3.0        64.0
# 0            NaN        NaN                     NaN     NaN         NaN
# 0            NaN        NaN                     NaN     NaN         NaN
# 0            NaN        NaN                     NaN     NaN         NaN
# 0            NaN        NaN                     NaN     NaN         NaN
# 0            NaN        NaN                     NaN     NaN         NaN
# 0            NaN        NaN                     NaN     NaN         NaN
# 0            NaN        NaN                     NaN     NaN         NaN
# 0           0.20        1.0                     NaN     NaN         NaN
# 0           0.10        1.0                     NaN     NaN         NaN
# 0           0.01        1.0                     NaN     NaN         NaN
#
#    num_lstm_cells  dropout_emb_lstm  dropout_lstm_dense  n_trees_in_forest  \
# 0            10.0               0.2                 0.2                NaN
# 0           100.0               0.2                 0.2                NaN
# 0            10.0               0.2                 0.2                NaN
# 0             NaN               NaN                 NaN              100.0
# 0             NaN               NaN                 NaN              100.0
# 0             NaN               NaN                 NaN              100.0
# 0             NaN               NaN                 NaN              100.0
# 0             NaN               NaN                 NaN              100.0
# 0             NaN               NaN                 NaN              100.0
# 0             NaN               NaN                 NaN              100.0
# 0             NaN               NaN                 NaN                NaN
# 0             NaN               NaN                 NaN                NaN
# 0             NaN               NaN                 NaN                NaN
#
#   max_features        input_src_path  max_vocab_size  window_size  step_size  \
# 0          NaN  second_large_dataset          100000           20          3
# 0          NaN  second_large_dataset          100000           20          3
# 0          NaN  second_large_dataset          100000           20          3
# 0         sqrt  second_large_dataset          100000           20          3
# 0         sqrt  second_large_dataset          100000           20          3
# 0         sqrt  second_large_dataset          100000           20          3
# 0         sqrt  second_large_dataset          100000           20          3
# 0         sqrt  second_large_dataset          100000           20          3
# 0         sqrt  second_large_dataset          100000           20          3
# 0         sqrt  second_large_dataset          100000           20          3
# 0          NaN  second_large_dataset          100000           20          3
# 0          NaN  second_large_dataset          100000           20          3
# 0          NaN  second_large_dataset          100000           20          3
#
#    encode_type  test_split_percentage
# 0        False                   0.25
# 0        False                   0.25
# 0        False                   0.25
# 0         True                   0.25
# 0         True                   0.25
# 0         True                   0.25
# 0        False                   0.25
# 0        False                   0.25
# 0         True                   0.25
# 0        False                   0.25
# 0         True                   0.25
# 0         True                   0.25
# 0         True                   0.25

# %%
return_condition_simple = results[results["problem_type"] == "CONDITION_COMPARISON_SIMPLE"] 
return_condition_simple.sort_values(by="f1", ascending=False)
# Out:
#                                              task_id  \
# 0            TaskEvaluateLstm_256_0_2_0_2_082adab389
# 0             TaskEvaluateLstm_64_0_2_0_2_aee4eaf776
# 0            TaskEvaluateLstm_256_0_2_0_2_08248931e9
# 0  TaskEvaluateRandomForest_True_second_large_dat...
# 0  TaskEvaluateRandomForest_True_second_large_dat...
# 0  TaskEvaluateRandomForest_False_second_large_da...
# 0  TaskEvaluateRandomForest_True_second_large_dat...
# 0  TaskEvaluateRandomForest_False_second_large_da...
# 0  TaskEvaluateRandomForest_False_second_large_da...
# 0  TaskEvaluateRandomForest_True_second_large_dat...
# 0  TaskEvaluateGradientBoostingClassifier_True_se...
# 0  TaskEvaluateGradientBoostingClassifier_True_se...
# 0  TaskEvaluateGradientBoostingClassifier_True_se...
#
#                   problem_type      f1  recall  precision     roc  \
# 0  CONDITION_COMPARISON_SIMPLE  0.9817  0.9796     0.9838  0.9999
# 0  CONDITION_COMPARISON_SIMPLE  0.9655  0.9987     0.9345  0.9998
# 0  CONDITION_COMPARISON_SIMPLE  0.9550  0.9991     0.9147  0.9999
# 0  CONDITION_COMPARISON_SIMPLE  0.9385  0.9014     0.9789  0.9991
# 0  CONDITION_COMPARISON_SIMPLE  0.9368  0.8984     0.9785  0.9991
# 0  CONDITION_COMPARISON_SIMPLE  0.9276  0.8859     0.9734  0.9991
# 0  CONDITION_COMPARISON_SIMPLE  0.9268  0.9228     0.9307  0.9989
# 0  CONDITION_COMPARISON_SIMPLE  0.9259  0.8828     0.9733  0.9991
# 0  CONDITION_COMPARISON_SIMPLE  0.8055  0.9673     0.6901  0.9981
# 0  CONDITION_COMPARISON_SIMPLE  0.8046  0.9701     0.6874  0.9983
# 0  CONDITION_COMPARISON_SIMPLE  0.5808  0.9609     0.4162  0.9891
# 0  CONDITION_COMPARISON_SIMPLE  0.4841  0.9136     0.3293  0.9795
# 0  CONDITION_COMPARISON_SIMPLE  0.4815  0.9135     0.3269  0.9788
#
#    oversampling_enabled  ratio_after_oversampling  undersampling_enabled  \
# 0                 False                       0.5                  False
# 0                 False                       0.5                   True
# 0                 False                       0.5                   True
# 0                  True                       0.5                  False
# 0                  True                       1.0                  False
# 0                  True                       0.5                  False
# 0                 False                       0.5                   True
# 0                  True                       1.0                  False
# 0                 False                       0.5                   True
# 0                 False                       0.5                   True
# 0                 False                       0.5                   True
# 0                 False                       0.5                   True
# 0                 False                       0.5                   True
#
#    ratio_after_undersampling                                 cm  \
# 0                        0.5     [[1326930, 587], [743, 35598]]
# 0                        0.5     [[1324974, 2543], [49, 36292]]
# 0                        0.5     [[1324131, 3386], [32, 36309]]
# 0                        0.5    [[1326810, 707], [3584, 32757]]
# 0                        0.5    [[1326799, 718], [3691, 32650]]
# 0                        0.5    [[1326638, 879], [4145, 32196]]
# 0                        0.1   [[1325021, 2496], [2805, 33536]]
# 0                        0.5    [[1326638, 879], [4258, 32083]]
# 0                        0.5  [[1311734, 15783], [1189, 35152]]
# 0                        0.5  [[1311483, 16034], [1085, 35256]]
# 0                        0.5  [[1278533, 48984], [1422, 34919]]
# 0                        0.5  [[1259885, 67632], [3139, 33202]]
# 0                        0.5  [[1259172, 68345], [3145, 33196]]
#
#                                        cm_normalized  n_estimators  \
# 0  [[0.999557821105115, 0.000442178894884], [0.02...           NaN
# 0  [[0.9980843936461831, 0.0019156063538160002], ...           NaN
# 0  [[0.9974493735296791, 0.0025506264703200002], ...           NaN
# 0  [[0.9994674267824811, 0.0005325732175180001], ...           NaN
# 0  [[0.9994591406362401, 0.000540859363759], [0.1...           NaN
# 0  [[0.9993378615867061, 0.000662138413293], [0.1...           NaN
# 0  [[0.998119798089214, 0.0018802019107850001], [...           NaN
# 0  [[0.9993378615867061, 0.000662138413293], [0.1...           NaN
# 0  [[0.9881108867155751, 0.011889113284424001], [...           NaN
# 0  [[0.987921811924065, 0.012078188075934], [0.02...           NaN
# 0  [[0.9631010375008381, 0.036898962499161005], [...         100.0
# 0  [[0.9490537597635281, 0.050946240236471006], [...        1000.0
# 0  [[0.9485166668298781, 0.05148333317012101], [0...         100.0
#
#    learning_rate  subsample  embedding_vecor_length  epochs  batch_size  \
# 0            NaN        NaN                    32.0     2.0       256.0
# 0            NaN        NaN                    32.0     3.0        64.0
# 0            NaN        NaN                    32.0     3.0       256.0
# 0            NaN        NaN                     NaN     NaN         NaN
# 0            NaN        NaN                     NaN     NaN         NaN
# 0            NaN        NaN                     NaN     NaN         NaN
# 0            NaN        NaN                     NaN     NaN         NaN
# 0            NaN        NaN                     NaN     NaN         NaN
# 0            NaN        NaN                     NaN     NaN         NaN
# 0            NaN        NaN                     NaN     NaN         NaN
# 0           0.20        1.0                     NaN     NaN         NaN
# 0           0.01        1.0                     NaN     NaN         NaN
# 0           0.10        1.0                     NaN     NaN         NaN
#
#    num_lstm_cells  dropout_emb_lstm  dropout_lstm_dense  n_trees_in_forest  \
# 0            10.0               0.2                 0.2                NaN
# 0            10.0               0.2                 0.2                NaN
# 0           100.0               0.2                 0.2                NaN
# 0             NaN               NaN                 NaN              100.0
# 0             NaN               NaN                 NaN              100.0
# 0             NaN               NaN                 NaN              100.0
# 0             NaN               NaN                 NaN              100.0
# 0             NaN               NaN                 NaN              100.0
# 0             NaN               NaN                 NaN              100.0
# 0             NaN               NaN                 NaN              100.0
# 0             NaN               NaN                 NaN                NaN
# 0             NaN               NaN                 NaN                NaN
# 0             NaN               NaN                 NaN                NaN
#
#   max_features        input_src_path  max_vocab_size  window_size  step_size  \
# 0          NaN  second_large_dataset          100000           20          3
# 0          NaN  second_large_dataset          100000           20          3
# 0          NaN  second_large_dataset          100000           20          3
# 0         sqrt  second_large_dataset          100000           20          3
# 0         sqrt  second_large_dataset          100000           20          3
# 0         sqrt  second_large_dataset          100000           20          3
# 0         sqrt  second_large_dataset          100000           20          3
# 0         sqrt  second_large_dataset          100000           20          3
# 0         sqrt  second_large_dataset          100000           20          3
# 0         sqrt  second_large_dataset          100000           20          3
# 0          NaN  second_large_dataset          100000           20          3
# 0          NaN  second_large_dataset          100000           20          3
# 0          NaN  second_large_dataset          100000           20          3
#
#    encode_type  test_split_percentage
# 0        False                   0.25
# 0        False                   0.25
# 0        False                   0.25
# 0         True                   0.25
# 0         True                   0.25
# 0        False                   0.25
# 0         True                   0.25
# 0        False                   0.25
# 0        False                   0.25
# 0         True                   0.25
# 0         True                   0.25
# 0         True                   0.25
# 0         True                   0.25
