# %%
import d6tflow
from tasks.preprocessing import ProblemType, TaskVocabCreator
from tasks.random_forest import TaskEvaluateRandomForest
# Out:
# Loading postgres module without psycopg2 installed. Will crash at runtime if postgres functionality is used.
# Loading S3 module without the python package boto3. Will crash at runtime if S3 functionality is used.
# Welcome to d6tflow!

# %%
d6tflow.settings.log_level = 'WARNING' # 'DEBUG', 'INFO', 'WARNING', 'ERROR', 'CRITICAL'

# %%
d6tflow.run(TaskVocabCreator(max_vocab_size=10000))
# Out:
# True

# %%
d6tflow.run(TaskEvaluateRandomForest(problem_type=ProblemType.CONDITION_COMPARISON, oversampling_enabled=True, ratio_after_oversampling=0.5, max_vocab_size=10000))
# Out:
# ###Running TaskTrainRandomForest
# Feature Distribution: Train: 33.333333333333336%, Test: 5.8252646054307515%
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  5.4min finished
# ###Running TaskEvaluateRandomForest
# Length Train: 3006171, length Test 709736
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:   17.8s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:   17.1s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# ...

# %%
d6tflow.run(TaskEvaluateRandomForest(problem_type=ProblemType.CONDITION_COMPARISON, oversampling_enabled=True, ratio_after_oversampling=1.0, max_vocab_size=10000))
# Out:
# ###Running TaskTrainTestSplit
# Length Train: 4008228, length Test 709736
# ###Running TaskTrainRandomForest
# Feature Distribution: Train: 50.0%, Test: 5.8252646054307515%
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  8.0min finished
# ###Running TaskEvaluateRandomForest
# Length Train: 4008228, length Test 709736
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:   24.6s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:   21.9s finished
# ...

# %%
d6tflow.run(TaskEvaluateRandomForest(problem_type=ProblemType.CONDITION_COMPARISON, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, max_vocab_size=10000))
# Out:
# ###Running TaskTrainTestSplit
# Length Train: 375282, length Test 709736
# ###Running TaskTrainRandomForest
# Feature Distribution: Train: 33.333333333333336%, Test: 5.8252646054307515%
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   22.1s finished
# ###Running TaskEvaluateRandomForest
# Length Train: 375282, length Test 709736
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:    1.3s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:    1.4s finished
# ...

# %%
d6tflow.run(TaskEvaluateRandomForest(problem_type=ProblemType.CONDITION_COMPARISON, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.1, max_vocab_size=10000))
# Out:
# ###Running TaskTrainTestSplit
# Length Train: 1376034, length Test 709736
# ###Running TaskTrainRandomForest
# Feature Distribution: Train: 9.090909090909092%, Test: 5.8252646054307515%
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   45.1s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  2.1min finished
# ###Running TaskEvaluateRandomForest
# Length Train: 1376034, length Test 709736
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:    5.0s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:    5.6s finished
# ...

# %% [markdown]
# # SVM

# %%
import d6tflow
from tasks.svm import TaskEvaluateSVM, TaskTrainSVM
from tasks.preprocessing import TaskTrainTestSplit
from tasks.preprocessing import ProblemType
# Out:
# Loading postgres module without psycopg2 installed. Will crash at runtime if postgres functionality is used.
# Loading S3 module without the python package boto3. Will crash at runtime if S3 functionality is used.
# Welcome to d6tflow!

# %%
d6tflow.run(TaskEvaluateSVM(problem_type=ProblemType.CONDITION_COMPARISON, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, svm_kernel="rbf", svm_predict_probability=True, max_vocab_size=10000))
# Out:
# INFO: Informed scheduler that task   TaskEvaluateSVM_raw_data_1000_False_fb8916dbe2   has status   PENDING
# INFO: Informed scheduler that task   TaskTrainTestSplit_raw_data_1000_False_c5afbc7f24   has status   PENDING
# INFO: Informed scheduler that task   TaskPrepareXY_raw_data_1000_CONDITION_COMPAR_8f31e07ae4   has status   PENDING
# INFO: Informed scheduler that task   TaskVocabCreator_raw_data_1000_9fddda5c27   has status   DONE
# INFO: Informed scheduler that task   TaskRuleProcessor_raw_data_94d91431be   has status   PENDING
# INFO: Informed scheduler that task   TaskSourceFileToDataStructure_raw_data_94d91431be   has status   DONE
# INFO: Informed scheduler that task   TaskTrainSVM_raw_data_1000_False_fb8916dbe2   has status   PENDING
# INFO: Done scheduling tasks
# INFO: Running Worker with 1 processes
# INFO: [pid 1601] Worker Worker(salt=895529062, workers=1, host=C02YV751LVDQ, username=d064518, pid=1601) running   TaskRuleProcessor(input_src_path=raw_data)
# ...

# %%
d6tflow.run(TaskEvaluateSVM(problem_type=ProblemType.CONDITION_COMPARISON, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.1, svm_kernel="rbf", svm_predict_probability=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e411611e9e0c> in <module>
# ----> 1 d6tflow.run(TaskEvaluateSVM(problem_type=ProblemType.CONDITION_COMPARISON, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.1, svm_kernel="rbf", svm_predict_probability=True))
#
# NameError: name 'TaskEvaluateSVM' is not defined

# %%
d6tflow.run(TaskEvaluateSVM(problem_type=ProblemType.CONDITION_COMPARISON, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, svm_kernel="rbf", svm_predict_probability=True, svm_class_weight="balanced", max_vocab_size=10000))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a42c3a93fbd0> in <module>
# ----> 1 d6tflow.run(TaskEvaluateSVM(problem_type=ProblemType.CONDITION_COMPARISON, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, svm_kernel="rbf", svm_predict_probability=True, svm_class_weight="balanced"))
#
# NameError: name 'TaskEvaluateSVM' is not defined

# %%
d6tflow.run(TaskEvaluateSVM(problem_type=ProblemType.CONDITION_COMPARISON, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.3, svm_kernel="rbf", svm_predict_probability=True, svm_class_weight="balanced", max_vocab_size=10000))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-fa65419a64e1> in <module>
# ----> 1 d6tflow.run(TaskEvaluateSVM(problem_type=ProblemType.CONDITION_COMPARISON, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.3, svm_kernel="rbf", svm_predict_probability=True, svm_class_weight="balanced"))
#
# NameError: name 'TaskEvaluateSVM' is not defined

# %% [markdown]
# # Gradient Boosting Trees

# %%
import d6tflow
from tasks.gradient_boosting_classifier import TaskEvaluateGradientBoostingClassifier, TaskTrainGradientBoostingClassifier
from tasks.preprocessing import TaskTrainTestSplit
from tasks.preprocessing import ProblemType

# %%
d6tflow.run(TaskEvaluateGradientBoostingClassifier(problem_type=ProblemType.CONDITION_COMPARISON, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, learning_rate=0.1, n_estimators=100, max_vocab_size=10000))
# Out:
# ###Running TaskTrainGradientBoostingClassifier
# Feature Distribution: Train: 33.333333333333336%, Test: 5.8252646054307515%
#       Iter       Train Loss   Remaining Time
#          1           1.2312            3.48m
#          2           1.1961            3.34m
#          3           1.1660            3.36m
#          4           1.1386            3.27m
#          5           1.1112            3.21m
#          6           1.0880            3.17m
#          7           1.0665            3.13m
#          8           1.0457            3.09m
#          9           1.0251            3.04m
#         10           1.0094            3.01m
#         20           0.8798            2.71m
#         30           0.7943            2.37m
#         40           0.7357            2.03m
#         50           0.6878            1.70m
#         60           0.6500            1.36m
#         70           0.6154            1.02m
#         80           0.5825           40.93s
# ...

# %%
d6tflow.run(TaskEvaluateGradientBoostingClassifier(problem_type=ProblemType.CONDITION_COMPARISON, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, learning_rate=0.2, n_estimators=100, max_vocab_size=10000))
# Out:
# ###Running TaskTrainGradientBoostingClassifier
# Feature Distribution: Train: 33.333333333333336%, Test: 5.8252646054307515%
#       Iter       Train Loss   Remaining Time
#          1           1.1938            3.25m
#          2           1.1385            3.26m
#          3           1.0846            3.21m
#          4           1.0475            3.19m
#          5           1.0098            3.16m
#          6           0.9767            3.15m
#          7           0.9493            3.20m
#          8           0.9213            3.18m
#          9           0.8999            3.11m
#         10           0.8746            3.07m
#         20           0.7218            2.73m
#         30           0.6370            2.34m
#         40           0.5710            2.02m
#         50           0.5016            1.68m
#         60           0.4517            1.35m
#         70           0.4128            1.02m
#         80           0.3834           40.61s
# ...

# %%
from models.random_forst import decode_vector
from tasks.preprocessing import TaskVocabCreator

df = TaskEvaluateGradientBoostingClassifier(problem_type=ProblemType.CONDITION_COMPARISON, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, learning_rate=0.1, n_estimators=100).outputLoad()
vocab = TaskVocabCreator().outputLoad()
reversed_vocab = dict([(value, key) for key, value in vocab.items()]) 

wrong_predicted = df[df["ground_truth"] == 1 ]#!= df["predicted"]]
wrong_predicted["decoded"] = wrong_predicted["x"].apply(lambda row: decode_vector(row, reversed_vocab))
wrong_predicted["src"] = wrong_predicted["decoded"].apply(lambda row: " ".join(row[1::2]))
wrong_predicted[wrong_predicted["ground_truth"] == 1]["src"].apply(lambda row: print(row))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-5b3163d063f3> in <module>
#       2 from tasks.preprocessing import TaskVocabCreator
#       3
# ----> 4 df = TaskEvaluateGradientBoostingClassifier(problem_type=ProblemType.CONDITION_COMPARISON, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, learning_rate=0.1, n_estimators=100).outputLoad()
#       5 vocab = TaskVocabCreator().outputLoad()
#       6 reversed_vocab = dict([(value, key) for key, value in vocab.items()])
#
# ~/.virtualenvs/own_classifier/lib/python3.8/site-packages/d6tflow/tasks/__init__.py in outputLoad(self, keys, as_dict, cached)
#     120         """
#     121         if not self.complete():
# --> 122             raise RuntimeError('Cannot load, task not complete, run flow first')
#     123         keys = self.persist if keys is None else keys
# ...

# %% [markdown]
# ## LSTM

# %%
from tasks.lstm import TaskEvaluateLstm
from tasks.preprocessing import ProblemType
import d6tflow

# %%
d6tflow.run(TaskEvaluateLstm(problem_type=ProblemType.CONDITION_COMPARISON, oversampling_enabled=False, undersampling_enabled=False, embedding_vecor_length=32, epochs=2, batch_size=256, encode_type=False, num_lstm_cells=10, dropout_emb_lstm=0.2, dropout_lstm_dense=0.2, max_vocab_size=10000))
# Out:
# ...
# 100%|██████████| 6623/6623 [01:57<00:00, 56.60it/s]
# ###Running TaskTrainTestSplit
# Length Train: 2129208, length Test 709736
# ###Running TaskTrainLstm
# Feature Distribution: Train: 5.875142306435069%, Test: 5.8252646054307515%
# length Train: 2129208, length Test: 709736
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding (Embedding)        (None, 20, 32)            320064
# _________________________________________________________________
# dropout (Dropout)            (None, 20, 32)            0
# _________________________________________________________________
# lstm (LSTM)                  (None, 10)                1720
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10)                0
# _________________________________________________________________
# ...

# %%
d6tflow.run(TaskEvaluateLstm(problem_type=ProblemType.CONDITION_COMPARISON, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, embedding_vecor_length=32, epochs=3, batch_size=256, encode_type=False, dropout_emb_lstm=0.2, dropout_lstm_dense=0.2, max_vocab_size=10000))
# Out:
# ###Running TaskTrainTestSplit
# Length Train: 375282, length Test 709736
# ###Running TaskTrainLstm
# Feature Distribution: Train: 33.333333333333336%, Test: 5.8252646054307515%
# length Train: 375282, length Test: 709736
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_1 (Embedding)      (None, 20, 32)            320064
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 20, 32)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               53200
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# ...
# Total params: 373,365
# ...

# %%
d6tflow.run(TaskEvaluateLstm(problem_type=ProblemType.CONDITION_COMPARISON, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, embedding_vecor_length=32, epochs=3, batch_size=64, encode_type=False, num_lstm_cells=10, dropout_emb_lstm=0.2, dropout_lstm_dense=0.2, max_vocab_size=10000))
# Out:
# ###Running TaskTrainLstm
# Feature Distribution: Train: 33.333333333333336%, Test: 5.8252646054307515%
# length Train: 375282, length Test: 709736
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_2 (Embedding)      (None, 20, 32)            320064
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 20, 32)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 10)                1720
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# ...
# Total params: 321,795
# Trainable params: 321,795
# Non-trainable params: 0
# ...
