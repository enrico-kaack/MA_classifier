# %%
import d6tflow
from tasks.preprocessing import ProblemType, TaskVocabCreator
from tasks.random_forest import TaskEvaluateRandomForest
# Out:
# Loading postgres module without psycopg2 installed. Will crash at runtime if postgres functionality is used.
# Loading S3 module without the python package boto3. Will crash at runtime if S3 functionality is used.
# Welcome to d6tflow!

# %%
d6tflow.settings.log_level = 'WARNING' # 'DEBUG', 'INFO', 'WARNING', 'ERROR', 'CRITICAL'

# %%
d6tflow.run(TaskVocabCreator(max_vocab_size=10000))
# Out:
# ###Running TaskSourceFileToDataStructure
# ...
# 100%|██████████| 6623/6623 [00:34<00:00, 193.62it/s]
# Unknown Token Frequency: 8.143538101749499%
# True

# %%
d6tflow.run(TaskEvaluateRandomForest(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=True, ratio_after_oversampling=0.5, max_vocab_size=10000))
# Out:
# ...
#  78%|███████▊  | 5193/6623 [02:05<00:21, 67.61it/s]WARNING:root:Syntax error on file:raw_data/ansible/ansible/devel/ansible-devel/test/support/windows-integration/collections/ansible_collections/ansible/windows/plugins/modules/win_shell.py. Ignoring file
# WARNING:root:Syntax error on file:raw_data/ansible/ansible/devel/ansible-devel/test/support/windows-integration/collections/ansible_collections/ansible/windows/plugins/modules/win_stat.py. Ignoring file
# WARNING:root:Syntax error on file:raw_data/ansible/ansible/devel/ansible-devel/test/support/windows-integration/collections/ansible_collections/ansible/windows/plugins/modules/win_copy.py. Ignoring file
# WARNING:root:Syntax error on file:raw_data/ansible/ansible/devel/ansible-devel/test/support/windows-integration/collections/ansible_collections/ansible/windows/plugins/modules/win_file.py. Ignoring file
# ...

# %%
d6tflow.run(TaskEvaluateRandomForest(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=True, ratio_after_oversampling=1.0, max_vocab_size=10000))
# Out:
# ###Running TaskTrainTestSplit
# Length Train: 4252908, length Test 709736
# ###Running TaskTrainRandomForest
# Feature Distribution: Train: 50.0%, Test: 0.12610322711543448%
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  5.8min finished
# ###Running TaskEvaluateRandomForest
# Length Train: 4252908, length Test 709736
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   19.1s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   21.4s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# ...

# %%
d6tflow.run(TaskEvaluateRandomForest(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, max_vocab_size=10000))
# Out:
# ###Running TaskTrainTestSplit
# Length Train: 8262, length Test 709736
# ###Running TaskTrainRandomForest
# Feature Distribution: Train: 33.333333333333336%, Test: 0.12610322711543448%
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.4s finished
# ###Running TaskEvaluateRandomForest
# Length Train: 8262, length Test 709736
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.0s finished
# ...

# %%
d6tflow.run(TaskEvaluateRandomForest(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.1, max_vocab_size=10000))
# Out:
# ###Running TaskTrainTestSplit
# Length Train: 30294, length Test 709736
# ###Running TaskTrainRandomForest
# Feature Distribution: Train: 9.090909090909092%, Test: 0.12610322711543448%
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    1.3s finished
# ###Running TaskEvaluateRandomForest
# Length Train: 30294, length Test 709736
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.1s finished
# ...

# %% [markdown]
# # SVM

# %%
import d6tflow
from tasks.svm import TaskEvaluateSVM, TaskTrainSVM
from tasks.preprocessing import TaskTrainTestSplit
from tasks.preprocessing import ProblemType

# %%
d6tflow.run(TaskEvaluateSVM(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, svm_kernel="rbf", svm_predict_probability=True, max_vocab_size=10000))
# Out:
# ###Running TaskTrainSVM
# Feature Distribution: Train: 33.333333333333336%, Test: 0.12610322711543448%
# [LibSVM]###Running TaskEvaluateSVM
# Length Train: 8262, length Test 709736
# Test Accuracy 0.9922027345379126
# Recall Baseline: 1.0 Test: 0.01 Train: 0.03
# Precision Baseline: 0.0 Test: 0.0 Train: 0.91
# Roc Baseline: 0.5 Test: 0.67 Train: 0.82
# Normalized confusion matrix
# [[0.99344282 0.00655718]
#  [0.98994413 0.01005587]]
# True

# %%
d6tflow.run(TaskEvaluateSVM(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.1, svm_kernel="rbf", svm_predict_probability=True, max_vocab_size=10000))
# Out:
# ###Running TaskTrainSVM
# Feature Distribution: Train: 9.090909090909092%, Test: 0.12610322711543448%
# [LibSVM]###Running TaskEvaluateSVM
# Length Train: 30294, length Test 709736
# Test Accuracy 0.9987389677288456
# Recall Baseline: 1.0 Test: 0.0 Train: 0.0
# Precision Baseline: 0.0 Test: 0.0 Train: 0.0
# Roc Baseline: 0.5 Test: 0.81 Train: 0.95
# Normalized confusion matrix
# [[1. 0.]
#  [1. 0.]]
# True

# %%
d6tflow.run(TaskEvaluateSVM(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, svm_kernel="rbf", svm_predict_probability=True, svm_class_weight="balanced", max_vocab_size=10000))
# Out:
# ###Running TaskTrainSVM
# Feature Distribution: Train: 33.333333333333336%, Test: 0.12610322711543448%
# [LibSVM]###Running TaskEvaluateSVM
# Length Train: 8262, length Test 709736
# Test Accuracy 0.4960717788022589
# Recall Baseline: 1.0 Test: 0.78 Train: 0.85
# Precision Baseline: 0.0 Test: 0.0 Train: 0.48
# Roc Baseline: 0.5 Test: 0.7 Train: 0.77
# Normalized confusion matrix
# [[0.49571484 0.50428516]
#  [0.22122905 0.77877095]]
# True

# %%
d6tflow.run(TaskEvaluateSVM(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.3, svm_kernel="rbf", svm_predict_probability=True, svm_class_weight="balanced", max_vocab_size=10000))
# Out:
# ###Running TaskTrainTestSplit
# Length Train: 11934, length Test 709736
# ###Running TaskTrainSVM
# Feature Distribution: Train: 23.076923076923077%, Test: 0.12610322711543448%
# [LibSVM]###Running TaskEvaluateSVM
# Length Train: 11934, length Test 709736
# Test Accuracy 0.5175896389643473
# Recall Baseline: 1.0 Test: 0.77 Train: 0.85
# Precision Baseline: 0.0 Test: 0.0 Train: 0.36
# Roc Baseline: 0.5 Test: 0.71 Train: 0.78
# Normalized confusion matrix
# [[0.51727679 0.48272321]
#  [0.23463687 0.76536313]]
# True

# %% [markdown]
# # Gradient Boosting Trees

# %%
import d6tflow
from tasks.gradient_boosting_classifier import TaskEvaluateGradientBoostingClassifier, TaskTrainGradientBoostingClassifier
from tasks.preprocessing import TaskTrainTestSplit
from tasks.preprocessing import ProblemType

# %%
d6tflow.run(TaskEvaluateGradientBoostingClassifier(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, learning_rate=0.1, n_estimators=100, max_vocab_size=10000))
# Out:
# ###Running TaskTrainGradientBoostingClassifier
# Feature Distribution: Train: 33.333333333333336%, Test: 0.12610322711543448%
#       Iter       Train Loss   Remaining Time
#          1           1.2252            3.69s
#          2           1.1827            3.22s
#          3           1.1460            3.05s
#          4           1.1126            2.95s
#          5           1.0813            2.90s
#          6           1.0507            2.85s
#          7           1.0263            2.81s
#          8           0.9995            2.78s
#          9           0.9757            2.73s
#         10           0.9544            2.68s
#         20           0.7812            2.32s
#         30           0.6635            2.01s
#         40           0.5712            1.73s
#         50           0.5042            1.45s
#         60           0.4475            1.15s
#         70           0.4028            0.86s
#         80           0.3630            0.57s
# ...

# %%
d6tflow.run(TaskEvaluateGradientBoostingClassifier(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, learning_rate=0.2, n_estimators=100, max_vocab_size=10000))
# Out:
# ###Running TaskTrainGradientBoostingClassifier
# Feature Distribution: Train: 33.333333333333336%, Test: 0.12610322711543448%
#       Iter       Train Loss   Remaining Time
#          1           1.1824            2.84s
#          2           1.1101            2.82s
#          3           1.0509            2.77s
#          4           1.0000            2.77s
#          5           0.9559            2.74s
#          6           0.9123            2.72s
#          7           0.8713            2.70s
#          8           0.8298            2.69s
#          9           0.7970            2.65s
#         10           0.7702            2.62s
#         20           0.5580            2.29s
#         30           0.4347            2.00s
#         40           0.3521            1.71s
#         50           0.2914            1.43s
#         60           0.2496            1.14s
#         70           0.2135            0.86s
#         80           0.1818            0.57s
# ...

# %%
from models.random_forst import decode_vector
from tasks.preprocessing import TaskVocabCreator

df = TaskEvaluateGradientBoostingClassifier(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, learning_rate=0.1, n_estimators=100, max_vocab_size=10000).outputLoad()
vocab = TaskVocabCreator(max_vocab_size=10000).outputLoad()
reversed_vocab = dict([(value, key) for key, value in vocab.items()]) 

wrong_predicted = df[df["ground_truth"] == 1 ]#!= df["predicted"]]
wrong_predicted["decoded"] = wrong_predicted["x"].apply(lambda row: decode_vector(row, reversed_vocab))
wrong_predicted["src"] = wrong_predicted["decoded"].apply(lambda row: " ".join(row[1::2]))
wrong_predicted[wrong_predicted["ground_truth"] == 1]["src"].apply(lambda row: print(row))
# Out:
#  ) :
#       if dt is none :
#           return none
#   try :
#
# if self . groups is none :
#               return none
#   info = self . <UNKNOWN> ( )
# grad ) :
#           return none
#
#   def <UNKNOWN> ( self , param , net ) :
#
#   return none
#
#   def load ( self ) :
#           self . _bytes = self
# :
#               return none
#   return ipv4address ( ( self . _ip >> 80 ) & <UNKNOWN> )
# torch . jit . script_method
#  def forward ( self , input ) :
#           return none
#
#
# cpu and dst . device_type == cpu :
#           return none
#
#   if <UNKNOWN> and <UNKNOWN> :
# return self . _parent . <UNKNOWN> ( )
#   else :
#                   return none
#    else
# ( fn ) :
#  <UNKNOWN>
#           return none
#
#   if isinstance ( fn , torch .
# none :
#               return none
#
#  <UNKNOWN>
#   if hasattr ( value , 'resolve_expression' ) :
#
#              return none
#   query = query ( model = model , <UNKNOWN> = false )
#  where =
# ( key ) :
# ...

# %% [markdown]
# ## LSTM

# %%
from tasks.lstm import TaskEvaluateLstm
from tasks.preprocessing import ProblemType
import d6tflow
# Out:
# Loading postgres module without psycopg2 installed. Will crash at runtime if postgres functionality is used.
# Loading S3 module without the python package boto3. Will crash at runtime if S3 functionality is used.
# Welcome to d6tflow!

# %%
d6tflow.run(TaskEvaluateLstm(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=False, undersampling_enabled=False, embedding_vecor_length=32, epochs=2, batch_size=256, encode_type=False, num_lstm_cells=10, dropout_emb_lstm=0.2, dropout_lstm_dense=0.2, max_vocab_size=10000))
# Out:
# INFO: Informed scheduler that task   TaskEvaluateLstm_256_0_2_0_2_5c12e6dc3f   has status   PENDING
# INFO: Informed scheduler that task   TaskTrainTestSplit_False_raw_data_10000_cd9eb1b198   has status   PENDING
# INFO: Informed scheduler that task   TaskPrepareXY_False_raw_data_10000_5b390760c8   has status   PENDING
# INFO: Informed scheduler that task   TaskVocabCreator_raw_data_10000_fdec0f164c   has status   DONE
# INFO: Informed scheduler that task   TaskRuleProcessor_raw_data_94d91431be   has status   DONE
# INFO: Informed scheduler that task   TaskTrainLstm_256_0_2_0_2_5c12e6dc3f   has status   PENDING
# INFO: Done scheduling tasks
# INFO: Running Worker with 1 processes
# INFO: [pid 6048] Worker Worker(salt=860014686, workers=1, host=C02YV751LVDQ, username=d064518, pid=6048) running   TaskPrepareXY(input_src_path=raw_data, max_vocab_size=10000, problem_type=RETURN_NONE, window_size=20, step_size=3, encode_type=False)
# ...
# 100%|██████████| 6623/6623 [01:10<00:00, 93.56it/s]
# ...

# %%
d6tflow.run(TaskEvaluateLstm(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, embedding_vecor_length=32, epochs=3, batch_size=256, encode_type=False, dropout_emb_lstm=0.2, dropout_lstm_dense=0.2, max_vocab_size=10000))
# Out:
# INFO: Informed scheduler that task   TaskEvaluateLstm_256_0_2_0_2_cdc24a4190   has status   PENDING
# INFO: Informed scheduler that task   TaskTrainTestSplit_False_raw_data_10000_95d149a289   has status   PENDING
# INFO: Informed scheduler that task   TaskPrepareXY_False_raw_data_10000_5b390760c8   has status   DONE
# INFO: Informed scheduler that task   TaskTrainLstm_256_0_2_0_2_cdc24a4190   has status   PENDING
# INFO: Done scheduling tasks
# INFO: Running Worker with 1 processes
# INFO: [pid 6048] Worker Worker(salt=182068850, workers=1, host=C02YV751LVDQ, username=d064518, pid=6048) running   TaskTrainTestSplit(input_src_path=raw_data, max_vocab_size=10000, problem_type=RETURN_NONE, window_size=20, step_size=3, encode_type=False, test_split_percentage=0.25, oversampling_enabled=False, ratio_after_oversampling=0.5, undersampling_enabled=True, ratio_after_undersampling=0.5)
# ###Running TaskTrainTestSplit
# Length Train: 8229, length Test 709736
# ...

# %%
d6tflow.run(TaskEvaluateLstm(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, embedding_vecor_length=32, epochs=3, batch_size=64, encode_type=False, num_lstm_cells=10, dropout_emb_lstm=0.2, dropout_lstm_dense=0.2, max_vocab_size=10000))
# Out:
# INFO: Informed scheduler that task   TaskEvaluateLstm_64_0_2_0_2_4e250eecac   has status   PENDING
# INFO: Informed scheduler that task   TaskTrainTestSplit_False_raw_data_10000_95d149a289   has status   DONE
# INFO: Informed scheduler that task   TaskTrainLstm_64_0_2_0_2_4e250eecac   has status   PENDING
# INFO: Done scheduling tasks
# INFO: Running Worker with 1 processes
# INFO: [pid 6048] Worker Worker(salt=415684563, workers=1, host=C02YV751LVDQ, username=d064518, pid=6048) running   TaskTrainLstm(input_src_path=raw_data, max_vocab_size=10000, problem_type=RETURN_NONE, window_size=20, step_size=3, encode_type=False, test_split_percentage=0.25, oversampling_enabled=False, ratio_after_oversampling=0.5, undersampling_enabled=True, ratio_after_undersampling=0.5, embedding_vecor_length=32, epochs=3, batch_size=64, num_lstm_cells=10, dropout_emb_lstm=0.2, dropout_lstm_dense=0.2)
# ###Running TaskTrainLstm
# Feature Distribution: Train: 33.333333333333336%, Test: 0.12765309918054038%
# ...

# %%
d6tflow.run(TaskEvaluateLstm(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=True, undersampling_enabled=False, ratio_after_oversampling=0.5, embedding_vecor_length=32, epochs=3, batch_size=64, encode_type=False, num_lstm_cells=10, dropout_emb_lstm=0.2, dropout_lstm_dense=0.2, max_vocab_size=10000))
