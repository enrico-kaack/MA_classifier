# %%
import d6tflow
from tasks.preprocessing import ProblemType, TaskVocabCreator
from tasks.random_forest import TaskEvaluateRandomForest
# Out:
# Loading postgres module without psycopg2 installed. Will crash at runtime if postgres functionality is used.
# Loading S3 module without the python package boto3. Will crash at runtime if S3 functionality is used.
# Welcome to d6tflow!

# %%
d6tflow.settings.log_level = 'WARNING' # 'DEBUG', 'INFO', 'WARNING', 'ERROR', 'CRITICAL'

# %%
d6tflow.run(TaskVocabCreator(max_vocab_size=1000))
# Out:
# ###Running TaskSourceFileToDataStructure
# ...
# 100%|██████████| 6623/6623 [00:38<00:00, 170.36it/s]
# Unknown Token Frequency: 15.246045188846074%
# True

# %%
d6tflow.run(TaskEvaluateRandomForest(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=True, ratio_after_oversampling=0.5))
# Out:
# ...
#  15%|█▍        | 977/6623 [00:18<03:40, 25.62it/s]WARNING:root:Syntax error on file:raw_data/ansible/ansible/devel/ansible-devel/test/support/windows-integration/collections/ansible_collections/ansible/windows/plugins/action/win_copy.py. Ignoring file
# WARNING:root:Syntax error on file:raw_data/ansible/ansible/devel/ansible-devel/test/support/windows-integration/collections/ansible_collections/ansible/windows/plugins/modules/win_stat.py. Ignoring file
# WARNING:root:Syntax error on file:raw_data/ansible/ansible/devel/ansible-devel/test/support/windows-integration/collections/ansible_collections/ansible/windows/plugins/modules/win_shell.py. Ignoring file
# WARNING:root:Syntax error on file:raw_data/ansible/ansible/devel/ansible-devel/test/support/windows-integration/collections/ansible_collections/ansible/windows/plugins/modules/win_file.py. Ignoring file
# ...

# %%
d6tflow.run(TaskEvaluateRandomForest(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=True, ratio_after_oversampling=1.0))
# Out:
#   File "<ipython-input-5-8a500e98297d>", line 1
#     d6tflow.run(TaskEvaluateRandomForest(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=True ratio_after_oversampling=1.0))
#                                                                                                          ^
# SyntaxError: invalid syntax

# %%
d6tflow.run(TaskEvaluateRandomForest(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5))
# Out:
# ###Running TaskTrainTestSplit
# Length Train: 8229, length Test 709736
# ###Running TaskTrainRandomForest
# Feature Distribution: Train: 33.333333333333336%, Test: 0.12765309918054038%
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.2s finished
# ###Running TaskEvaluateRandomForest
# Length Train: 8229, length Test 709736
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:    0.0s finished
# ...

# %%
d6tflow.run(TaskEvaluateRandomForest(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.1))
# Out:
# ###Running TaskTrainTestSplit
# Length Train: 30173, length Test 709736
# ###Running TaskTrainRandomForest
# Feature Distribution: Train: 9.090909090909092%, Test: 0.12765309918054038%
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.5s finished
# ###Running TaskEvaluateRandomForest
# Length Train: 30173, length Test 709736
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:    0.1s finished
# ...

# %% [markdown]
# # SVM

# %%
import d6tflow
from tasks.svm import TaskEvaluateSVM, TaskTrainSVM
from tasks.preprocessing import TaskTrainTestSplit
from tasks.preprocessing import ProblemType

# %%
d6tflow.run(TaskEvaluateSVM(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, svm_kernel="rbf", svm_predict_probability=True))
# Out:
# ###Running TaskTrainSVM
# Feature Distribution: Train: 33.333333333333336%, Test: 0.12765309918054038%
# [LibSVM]###Running TaskEvaluateSVM
# Length Train: 8229, length Test 709736
# Test Accuracy 0.9236378033522323
# Recall Baseline: 1.0 Test: 0.66 Train: 0.71
# Precision Baseline: 0.0 Test: 0.01 Train: 0.86
# Roc Baseline: 0.5 Test: 0.91 Train: 0.94
# Normalized confusion matrix
# [[0.92398036 0.07601964]
#  [0.34437086 0.65562914]]
# True

# %%
d6tflow.run(TaskEvaluateSVM(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.1, svm_kernel="rbf", svm_predict_probability=True))
# Out:
# ###Running TaskTrainSVM
# Feature Distribution: Train: 9.090909090909092%, Test: 0.12765309918054038%
# [LibSVM]###Running TaskEvaluateSVM
# Length Train: 30173, length Test 709736
# Test Accuracy 0.99872206003359
# Recall Baseline: 1.0 Test: 0.0 Train: 0.0
# Precision Baseline: 0.0 Test: 0.0 Train: 1.0
# Roc Baseline: 0.5 Test: 0.94 Train: 0.96
# Normalized confusion matrix
# [[9.99998589e-01 1.41077550e-06]
#  [1.00000000e+00 0.00000000e+00]]
# True

# %%
d6tflow.run(TaskEvaluateSVM(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, svm_kernel="rbf", svm_predict_probability=True, svm_class_weight="balanced"))
# Out:
# ###Running TaskTrainSVM
# Feature Distribution: Train: 33.333333333333336%, Test: 0.12765309918054038%
# [LibSVM]###Running TaskEvaluateSVM
# Length Train: 8229, length Test 709736
# Test Accuracy 0.7847185432329767
# Recall Baseline: 1.0 Test: 0.87 Train: 0.9
# Precision Baseline: 0.0 Test: 0.01 Train: 0.7
# Roc Baseline: 0.5 Test: 0.91 Train: 0.94
# Normalized confusion matrix
# [[0.78461549 0.21538451]
#  [0.13465784 0.86534216]]
# True

# %%
d6tflow.run(TaskEvaluateSVM(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.3, svm_kernel="rbf", svm_predict_probability=True, svm_class_weight="balanced"))
# Out:
# ###Running TaskTrainTestSplit
# Length Train: 11886, length Test 709736
# ###Running TaskTrainSVM
# Feature Distribution: Train: 23.077570250715127%, Test: 0.12765309918054038%
# [LibSVM]###Running TaskEvaluateSVM
# Length Train: 11886, length Test 709736
# Test Accuracy 0.8102984771802473
# Recall Baseline: 1.0 Test: 0.87 Train: 0.91
# Precision Baseline: 0.0 Test: 0.01 Train: 0.62
# Roc Baseline: 0.5 Test: 0.92 Train: 0.95
# Normalized confusion matrix
# [[0.8102253  0.1897747 ]
#  [0.13245033 0.86754967]]
# True

# %% [markdown]
# # Gradient Boosting Trees

# %%
import d6tflow
from tasks.gradient_boosting_classifier import TaskEvaluateGradientBoostingClassifier, TaskTrainGradientBoostingClassifier
from tasks.preprocessing import TaskTrainTestSplit
from tasks.preprocessing import ProblemType

# %%
d6tflow.run(TaskEvaluateGradientBoostingClassifier(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, learning_rate=0.1, n_estimators=100))
# Out:
# ###Running TaskTrainGradientBoostingClassifier
# Feature Distribution: Train: 33.333333333333336%, Test: 0.12765309918054038%
#       Iter       Train Loss   Remaining Time
#          1           1.2264            2.10s
#          2           1.1820            2.11s
#          3           1.1482            2.08s
#          4           1.1139            2.07s
#          5           1.0813            2.04s
#          6           1.0497            2.01s
#          7           1.0230            1.99s
#          8           0.9982            1.96s
#          9           0.9758            1.94s
#         10           0.9532            1.92s
#         20           0.7817            1.70s
#         30           0.6656            1.49s
#         40           0.5754            1.28s
#         50           0.5069            1.07s
#         60           0.4525            0.85s
#         70           0.4059            0.65s
#         80           0.3683            0.44s
# ...

# %%
d6tflow.run(TaskEvaluateGradientBoostingClassifier(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, learning_rate=0.2, n_estimators=100))
# Out:
# ###Running TaskTrainGradientBoostingClassifier
# Feature Distribution: Train: 33.333333333333336%, Test: 0.12765309918054038%
#       Iter       Train Loss   Remaining Time
#          1           1.1848            2.50s
#          2           1.1118            2.51s
#          3           1.0483            2.48s
#          4           0.9971            2.45s
#          5           0.9519            2.41s
#          6           0.9118            2.33s
#          7           0.8734            2.27s
#          8           0.8370            2.21s
#          9           0.8072            2.17s
#         10           0.7808            2.15s
#         20           0.5827            1.91s
#         30           0.4578            1.61s
#         40           0.3716            1.35s
#         50           0.3099            1.13s
#         60           0.2651            0.90s
#         70           0.2272            0.69s
#         80           0.1972            0.46s
# ...

# %%
from models.random_forst import decode_vector
from tasks.preprocessing import TaskVocabCreator

df = TaskEvaluateGradientBoostingClassifier(problem_type=ProblemType.RETURN_NONE, oversampling_enabled=False, undersampling_enabled=True, ratio_after_undersampling=0.5, learning_rate=0.1, n_estimators=100).outputLoad()
vocab = TaskVocabCreator().outputLoad()
reversed_vocab = dict([(value, key) for key, value in vocab.items()]) 

wrong_predicted = df[df["ground_truth"] == 1 ]#!= df["predicted"]]
wrong_predicted["decoded"] = wrong_predicted["x"].apply(lambda row: decode_vector(row, reversed_vocab))
wrong_predicted["src"] = wrong_predicted["decoded"].apply(lambda row: " ".join(row[1::2]))
wrong_predicted[wrong_predicted["ground_truth"] == 1]["src"].apply(lambda row: print(row))
# Out:
# OWN> [ <UNKNOWN> ] :
#           return none
#
#
#  return none
#   return other | self
#
#   def <UNKNOWN> ( self , other ) :
# <UNKNOWN>
#               return none
#  <UNKNOWN>
#   <UNKNOWN> = iter ( params )
#  query , <UNKNOWN> =
# ( "/" , <UNKNOWN> = "foo" )
#  def sub ( ) :
#           return none
#
#
# runtimeerror :
#               pass
#    return none
#
#
#   def <UNKNOWN> ( g , input
# <UNKNOWN> ( )
#  return none
#
#     def __str__ ( self ) :
#           return
# <UNKNOWN> )
#    return none
#
#
#    class <UNKNOWN> ( <UNKNOWN> ) :
#
#
#
#           module . fail_json ( msg = <UNKNOWN> )
#   else :
#           return none
#
#
# <UNKNOWN> = true
#  return none <UNKNOWN>
#
#  <UNKNOWN>
#   request . <UNKNOWN> = false
#  return response
# <UNKNOWN> ) :
#           return none
#   elif weights == <UNKNOWN> :
#  <UNKNOWN>
#  <UNKNOWN>
#  <UNKNOWN>
#
#               return none
#
#  <UNKNOWN>
#   if request . method not in ( <UNKNOWN> , <UNKNOWN> ,
# ...
